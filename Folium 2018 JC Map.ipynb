# %%
import folium
from folium import plugins
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import branca
import glob
import datetime


# %matplotlib inline

# %%
files = glob.glob('data/JC-2018*.csv')
files
# Out:
# ['data/JC-201801-citibike-tripdata.csv',
#  'data/JC-201802-citibike-tripdata.csv',
#  'data/JC-201803-citibike-tripdata.csv',
#  'data/JC-201804-citibike-tripdata.csv',
#  'data/JC-201805-citibike-tripdata.csv',
#  'data/JC-201806-citibike-tripdata.csv',
#  'data/JC-201807-citibike-tripdata.csv',
#  'data/JC-201808-citibike-tripdata.csv',
#  'data/JC-201809-citibike-tripdata.csv',
#  'data/JC-201810-citibike-tripdata.csv',
#  'data/JC-201811-citibike-tripdata.csv',
#  'data/JC-201812-citibike-tripdata.csv']

# %%
df = pd.DataFrame()

for file in files:
    temp = pd.read_csv(file) #load each montly data csv
    temp.rename(str.lower, axis='columns', inplace = True) #standardize column names
    temp.columns = temp.columns.str.replace(" ","")
    df = df.append(temp) #combine into sinlge dataframe

df.reset_index(inplace = True) #create a new overall index

# %%
df.columns = df.columns.str.replace(" ","")

# %%
df.starttime = pd.to_datetime(df.starttime)
df.stoptime = pd.to_datetime(df.stoptime)
df['month'] = df['starttime'].dt.month

# %%
df.head()
# Out:
#    index  tripduration               starttime                stoptime  \
# 0      0           932 2018-01-01 02:06:17.541 2018-01-01 02:21:50.027
# 1      1           550 2018-01-01 12:06:18.039 2018-01-01 12:15:28.443
# 2      2           510 2018-01-01 12:06:56.978 2018-01-01 12:15:27.810
# 3      3           354 2018-01-01 14:53:10.186 2018-01-01 14:59:05.096
# 4      4           250 2018-01-01 17:34:30.192 2018-01-01 17:38:40.984
#
#    startstationid startstationname  startstationlatitude  \
# 0            3183   Exchange Place             40.716247
# 1            3183   Exchange Place             40.716247
# 2            3183   Exchange Place             40.716247
# 3            3183   Exchange Place             40.716247
# 4            3183   Exchange Place             40.716247
#
#    startstationlongitude  endstationid endstationname  endstationlatitude  \
# 0             -74.033459          3199   Newport Pkwy           40.728745
# 1             -74.033459          3199   Newport Pkwy           40.728745
# 2             -74.033459          3199   Newport Pkwy           40.728745
# 3             -74.033459          3267   Morris Canal           40.712419
# 4             -74.033459          3639     Harborside           40.719252
#
#    endstationlongitude  bikeid    usertype  birthyear  gender  month
# 0           -74.032108   31929  Subscriber       1992       1      1
# 1           -74.032108   31845  Subscriber       1969       2      1
# 2           -74.032108   31708  Subscriber       1946       1      1
# 3           -74.038526   31697  Subscriber       1994       1      1
# 4           -74.034234   31861  Subscriber       1991       1      1

# %%
station = df[['startstationname', 'startstationlongitude', 'startstationlatitude']]
station = station.drop_duplicates('startstationname')
station.reset_index(drop = True, inplace = True)
#station.head()

# %%
start = df.groupby('startstationname').size().reset_index().rename(columns={'startstationname': 'station', 0:'startcount'})
end = df.groupby('endstationname').size().reset_index().rename(columns={'endstationname': 'station', 0:'endcount'})
end = end[end['station'].isin(df.startstationname.unique())].reset_index(drop = True)
use = pd.merge(start, end)
use['total'] = use['startcount'] + use['endcount']

# %%
station.rename(columns={'startstationname': 'station', 'startstationlatitude': 'latitude','startstationlongitude': 'longitude' }, inplace = True)

# %%
station = pd.merge(station, use)

# %%
station.drop(50, inplace=True)

# %%
station.sort_values('station', inplace=True)

# %%
station.reset_index(drop=True, inplace=True)
station
# Out:
#                     station  longitude   latitude  startcount  endcount  total
# 0         5 Corners Library -74.059503  40.734961        2026      1751   3777
# 1               Astor Place -74.071262  40.719282        2898      2946   5844
# 2     Baldwin at Montgomery -74.064194  40.723659        4069      3464   7533
# 3              Bayside Park -74.082080  40.698651          34        31     65
# 4                Bergen Ave -74.071455  40.722104        2416      2105   4521
# 5            Bethune Center -74.085931  40.704958          24        24     48
# 6           Brunswick & 6th -74.050389  40.726012        8251      7297  15548
# 7              Brunswick St -74.050656  40.724176        7383      6817  14200
# 8           Christ Hospital -74.050444  40.734786        2420      1635   4055
# 9                 City Hall -74.043845  40.717733        8829      9469  18298
# 10            Columbia Park -74.096937  40.697030          14        22     36
# 11           Columbus Drive -74.038914  40.718355        7157      7124  14281
# 12  Communipaw & Berry Lane -74.066611  40.714358        1404      1456   2860
# 13      Danforth Light Rail -74.088012  40.692640          19        16     35
# 14                   Dey St -74.066921  40.737711        1168      1617   2785
# 15              Dixon Mills -74.049968  40.721630        5757      5238  10995
# 16         Essex Light Rail -74.036486  40.712774        6440      7107  13547
# 17           Exchange Place -74.033459  40.716247       18970     24105  43075
# 18            Fairmount Ave -74.071959  40.725726        2532      1925   4457
# 19     Garfield Ave Station -74.070039  40.710467         155       171    326
# 20             Glenwood Ave -74.071061  40.727551        1159       819   1978
# 21                 Grand St -74.037683  40.715178        4252      4057   8309
# 22            Grove St PATH -74.043117  40.719586       40931     50623  91554
# 23            Hamilton Park -74.044247  40.727596       20867     19661  40528
# 24               Harborside -74.034234  40.719252       12105     11640  23745
# 25         Heights Elevator -74.040443  40.748716        2567      2432   4999
# 26                  Hilltop -74.057574  40.731169        3076      2401   5477
# 27        JC Medical Center -74.049638  40.716540        5046      5336  10382
# 28               JCBS Depot -74.068601  40.709651          53       221    274
# 29           Jackson Square -74.078900  40.711130         396       343    739
# 30             Jersey & 3rd -74.045953  40.723332        7973      7273  15246
# 31          Jersey & 6th St -74.045572  40.725289        8035      6235  14270
# 32           Journal Square -74.062500  40.733670        5819      5300  11119
# 33           Lafayette Park -74.062859  40.713464        1913      2044   3957
# 34      Leonard Gordon Park -74.057271  40.745910        2685      2455   5140
# 35       Liberty Light Rail -74.055701  40.711242        7091      7392  14483
# 36             Lincoln Park -74.078406  40.724605        2574      3218   5792
# 37           MLK Light Rail -74.078885  40.711130          47        32     79
# 38             Manila & 1st -74.042884  40.721651        6527      6876  13403
# 39         Marin Light Rail -74.042817  40.714584       10371     10117  20488
# 40          McGinley Square -74.067622  40.725340        5629      4358   9987
# 41         Monmouth and 6th -74.048790  40.725685        5894      5744  11638
# 42            Montgomery St -74.050990  40.719420        2624      2419   5043
# 43             Morris Canal -74.038526  40.712419       10534      8967  19501
# 44                     NJCU -74.085849  40.710109          49        51    100
# 45               Newark Ave -74.046305  40.721525        9462      9583  19045
# 46             Newport PATH -74.033759  40.727224       15247     16326  31573
# 47             Newport Pkwy -74.032108  40.728745       10108     10036  20144
# 48              Oakland Ave -74.052478  40.737604        5384      4049   9433
# 49              Paulus Hook -74.033552  40.714145        8718      8226  16944
# 50           Pershing Field -74.051789  40.742677        4426      4129   8555
# 51           Riverview Park -74.043991  40.744319        2075      1733   3808
# 52                  Sip Ave -74.063784  40.730743       18184     16310  34494
# 53                 Union St -74.083639  40.718211        1015      1300   2315
# 54           Van Vorst Park -74.047727  40.718489        9145      7939  17084
# 55                Warren St -74.038051  40.721124        9258      9233  18491
# 56     West Side Light Rail -74.088772  40.714402          42        96    138
# 57                  York St -74.041050  40.716490        3301      3040   6341

# %%
def my_color_function(feature):
    """Maps low values to green and hugh values to red."""
    if feature < station.total.quantile(.2):
        return '#FFF5EE'
    elif feature < station.total.quantile(.4):
        return '#FAD6A5'
    elif feature < station.total.quantile(.6):
        return '#FFB347'
    elif feature < station.total.quantile(.8):
        return '#FF8C00'
    else:
        return '#996515'

# %%
m = folium.Map([station['latitude'].mean(), station['longitude'].mean()],
               tiles='Stamen Toner',
               zoom_start =14)

# mark each station as a point
for index, row in station.iterrows():
    
    html="""
    {name}
    {total}
    """.format(name=row['station'], start = row['startcount'], end = row['endcount'], total = row['total'])
    
    iframe = branca.element.IFrame(html=html, width=200, height=150)

    folium.RegularPolygonMarker([row['latitude'], row['longitude']],
                        radius=12,
                        color= 'black',
                        fill_color= my_color_function(row['total']),
                        popup=html,
                        ).add_to(m)

stationArr = list()

for index, row in station.iterrows():
   x = [row['latitude'], row['longitude']]
   stationArr.append(x)

m.save('map2018.html')

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
start = df.groupby(['startstationname', 'month']).size().reset_index().rename(columns={'startstationname': 'station', 0:'startcount'})
end = df.groupby(['endstationname', 'month']).size().reset_index().rename(columns={'endstationname': 'station', 0:'endcount'})
end = end[end['station'].isin(df.startstationname.unique())].reset_index(drop = True)
monthly_use = pd.merge(start, end)
monthly_use['total'] = use['startcount'] + use['endcount']

# %%
months = monthly_use.station.value_counts()

# %%
months['Bethune Center'] = months['Bethune Center'] + 1

# %%
months['Bayside Park'] = months['Bayside Park'] + 1

# %%
months = pd.DataFrame(months)

# %%
months
# Out:
#                          station
# Harborside                    12
# Liberty Light Rail            12
# Exchange Place                12
# McGinley Square               12
# Hamilton Park                 12
# Brunswick & 6th               12
# Morris Canal                  12
# Jersey & 3rd                  12
# Jersey & 6th St               12
# Dey St                        12
# Manila & 1st                  12
# Newark Ave                    12
# Baldwin at Montgomery         12
# 5 Corners Library             12
# Essex Light Rail              12
# Heights Elevator              12
# Pershing Field                12
# Dixon Mills                   12
# Newport PATH                  12
# Van Vorst Park                12
# Lafayette Park                12
# Sip Ave                       12
# Marin Light Rail              12
# Brunswick St                  12
# Washington St                 12
# Hilltop                       12
# Monmouth and 6th              12
# JC Medical Center             12
# Union St                      12
# Astor Place                   12
# Lincoln Park                  12
# York St                       12
# Leonard Gordon Park           12
# Communipaw & Berry Lane       12
# Oakland Ave                   12
# Paulus Hook                   12
# Newport Pkwy                  12
# City Hall                     12
# Journal Square                12
# Riverview Park                12
# Christ Hospital               12
# Grove St PATH                 12
# Warren St                     12
# Columbus Drive                12
# JCBS Depot                    10
# Glenwood Ave                   9
# Montgomery St                  9
# Bergen Ave                     9
# Fairmount Ave                  9
# Grand St                       9
# Jackson Square                 6
# MLK Light Rail                 4
# Columbia Park                  4
# NJCU                           4
# Bethune Center                 5
# Garfield Ave Station           4
# West Side Light Rail           4
# Bayside Park                   5
# Danforth Light Rail            4

# %%
months.drop('JCBS Depot', inplace=True)

# %%
months.reset_index(inplace = True)

# %%
months.rename(columns={'index': 'station', 'station':'months'}, inplace=True)

# %%
months.sort_values('station', inplace=True)

# %%
months.reset_index(drop=True,inplace = True)

# %%
months
# Out:
#                     station  months
# 0         5 Corners Library      12
# 1               Astor Place      12
# 2     Baldwin at Montgomery      12
# 3              Bayside Park       5
# 4                Bergen Ave       9
# 5            Bethune Center       5
# 6           Brunswick & 6th      12
# 7              Brunswick St      12
# 8           Christ Hospital      12
# 9                 City Hall      12
# 10            Columbia Park       4
# 11           Columbus Drive      12
# 12  Communipaw & Berry Lane      12
# 13      Danforth Light Rail       4
# 14                   Dey St      12
# 15              Dixon Mills      12
# 16         Essex Light Rail      12
# 17           Exchange Place      12
# 18            Fairmount Ave       9
# 19     Garfield Ave Station       4
# 20             Glenwood Ave       9
# 21                 Grand St       9
# 22            Grove St PATH      12
# 23            Hamilton Park      12
# 24               Harborside      12
# 25         Heights Elevator      12
# 26                  Hilltop      12
# 27        JC Medical Center      12
# 28           Jackson Square       6
# 29             Jersey & 3rd      12
# 30          Jersey & 6th St      12
# 31           Journal Square      12
# 32           Lafayette Park      12
# 33      Leonard Gordon Park      12
# 34       Liberty Light Rail      12
# 35             Lincoln Park      12
# 36           MLK Light Rail       4
# 37             Manila & 1st      12
# 38         Marin Light Rail      12
# 39          McGinley Square      12
# 40         Monmouth and 6th      12
# 41            Montgomery St       9
# 42             Morris Canal      12
# 43                     NJCU       4
# 44               Newark Ave      12
# 45             Newport PATH      12
# 46             Newport Pkwy      12
# 47              Oakland Ave      12
# 48              Paulus Hook      12
# 49           Pershing Field      12
# 50           Riverview Park      12
# 51                  Sip Ave      12
# 52                 Union St      12
# 53           Van Vorst Park      12
# 54                Warren St      12
# 55            Washington St      12
# 56     West Side Light Rail       4
# 57                  York St      12

# %%
station['months'] = months['months']

# %%
station
# Out:
#                     station  longitude   latitude  startcount  endcount  \
# 0         5 Corners Library -74.059503  40.734961        2026      1751
# 1               Astor Place -74.071262  40.719282        2898      2946
# 2     Baldwin at Montgomery -74.064194  40.723659        4069      3464
# 3              Bayside Park -74.082080  40.698651          34        31
# 4                Bergen Ave -74.071455  40.722104        2416      2105
# 5            Bethune Center -74.085931  40.704958          24        24
# 6           Brunswick & 6th -74.050389  40.726012        8251      7297
# 7              Brunswick St -74.050656  40.724176        7383      6817
# 8           Christ Hospital -74.050444  40.734786        2420      1635
# 9                 City Hall -74.043845  40.717733        8829      9469
# 10            Columbia Park -74.096937  40.697030          14        22
# 11           Columbus Drive -74.038914  40.718355        7157      7124
# 12  Communipaw & Berry Lane -74.066611  40.714358        1404      1456
# 13      Danforth Light Rail -74.088012  40.692640          19        16
# 14                   Dey St -74.066921  40.737711        1168      1617
# 15              Dixon Mills -74.049968  40.721630        5757      5238
# 16         Essex Light Rail -74.036486  40.712774        6440      7107
# 17           Exchange Place -74.033459  40.716247       18970     24105
# 18            Fairmount Ave -74.071959  40.725726        2532      1925
# 19     Garfield Ave Station -74.070039  40.710467         155       171
# 20             Glenwood Ave -74.071061  40.727551        1159       819
# 21                 Grand St -74.037683  40.715178        4252      4057
# 22            Grove St PATH -74.043117  40.719586       40931     50623
# 23            Hamilton Park -74.044247  40.727596       20867     19661
# 24               Harborside -74.034234  40.719252       12105     11640
# 25         Heights Elevator -74.040443  40.748716        2567      2432
# 26                  Hilltop -74.057574  40.731169        3076      2401
# 27        JC Medical Center -74.049638  40.716540        5046      5336
# 28               JCBS Depot -74.068601  40.709651          53       221
# 29           Jackson Square -74.078900  40.711130         396       343
# 30             Jersey & 3rd -74.045953  40.723332        7973      7273
# 31          Jersey & 6th St -74.045572  40.725289        8035      6235
# 32           Journal Square -74.062500  40.733670        5819      5300
# 33           Lafayette Park -74.062859  40.713464        1913      2044
# 34      Leonard Gordon Park -74.057271  40.745910        2685      2455
# 35       Liberty Light Rail -74.055701  40.711242        7091      7392
# 36             Lincoln Park -74.078406  40.724605        2574      3218
# 37           MLK Light Rail -74.078885  40.711130          47        32
# 38             Manila & 1st -74.042884  40.721651        6527      6876
# 39         Marin Light Rail -74.042817  40.714584       10371     10117
# 40          McGinley Square -74.067622  40.725340        5629      4358
# 41         Monmouth and 6th -74.048790  40.725685        5894      5744
# 42            Montgomery St -74.050990  40.719420        2624      2419
# 43             Morris Canal -74.038526  40.712419       10534      8967
# 44                     NJCU -74.085849  40.710109          49        51
# 45               Newark Ave -74.046305  40.721525        9462      9583
# 46             Newport PATH -74.033759  40.727224       15247     16326
# 47             Newport Pkwy -74.032108  40.728745       10108     10036
# 48              Oakland Ave -74.052478  40.737604        5384      4049
# 49              Paulus Hook -74.033552  40.714145        8718      8226
# 50           Pershing Field -74.051789  40.742677        4426      4129
# 51           Riverview Park -74.043991  40.744319        2075      1733
# 52                  Sip Ave -74.063784  40.730743       18184     16310
# 53                 Union St -74.083639  40.718211        1015      1300
# 54           Van Vorst Park -74.047727  40.718489        9145      7939
# 55                Warren St -74.038051  40.721124        9258      9233
# 56     West Side Light Rail -74.088772  40.714402          42        96
# 57                  York St -74.041050  40.716490        3301      3040
#
#     total  months
# 0    3777      12
# 1    5844      12
# 2    7533      12
# 3      65       5
# 4    4521       9
# 5      48       5
# 6   15548      12
# 7   14200      12
# 8    4055      12
# 9   18298      12
# 10     36       4
# 11  14281      12
# 12   2860      12
# 13     35       4
# 14   2785      12
# 15  10995      12
# 16  13547      12
# 17  43075      12
# 18   4457       9
# 19    326       4
# 20   1978       9
# 21   8309       9
# 22  91554      12
# 23  40528      12
# 24  23745      12
# 25   4999      12
# 26   5477      12
# 27  10382      12
# 28    274       6
# 29    739      12
# 30  15246      12
# 31  14270      12
# 32  11119      12
# 33   3957      12
# 34   5140      12
# 35  14483      12
# 36   5792       4
# 37     79      12
# 38  13403      12
# 39  20488      12
# 40   9987      12
# 41  11638       9
# 42   5043      12
# 43  19501       4
# 44    100      12
# 45  19045      12
# 46  31573      12
# 47  20144      12
# 48   9433      12
# 49  16944      12
# 50   8555      12
# 51   3808      12
# 52  34494      12
# 53   2315      12
# 54  17084      12
# 55  18491      12
# 56    138       4
# 57   6341      12

# %%
station['avgtotal'] = (station['total']/station['months']).round(1)
station['avgstart'] = (station['startcount']/station['months']).round(1)
station['avgend'] = (station['endcount']/station['months']).round(1)

# %%
station
# Out:
#                     station  longitude   latitude  startcount  endcount  \
# 0         5 Corners Library -74.059503  40.734961        2026      1751
# 1               Astor Place -74.071262  40.719282        2898      2946
# 2     Baldwin at Montgomery -74.064194  40.723659        4069      3464
# 3              Bayside Park -74.082080  40.698651          34        31
# 4                Bergen Ave -74.071455  40.722104        2416      2105
# 5            Bethune Center -74.085931  40.704958          24        24
# 6           Brunswick & 6th -74.050389  40.726012        8251      7297
# 7              Brunswick St -74.050656  40.724176        7383      6817
# 8           Christ Hospital -74.050444  40.734786        2420      1635
# 9                 City Hall -74.043845  40.717733        8829      9469
# 10            Columbia Park -74.096937  40.697030          14        22
# 11           Columbus Drive -74.038914  40.718355        7157      7124
# 12  Communipaw & Berry Lane -74.066611  40.714358        1404      1456
# 13      Danforth Light Rail -74.088012  40.692640          19        16
# 14                   Dey St -74.066921  40.737711        1168      1617
# 15              Dixon Mills -74.049968  40.721630        5757      5238
# 16         Essex Light Rail -74.036486  40.712774        6440      7107
# 17           Exchange Place -74.033459  40.716247       18970     24105
# 18            Fairmount Ave -74.071959  40.725726        2532      1925
# 19     Garfield Ave Station -74.070039  40.710467         155       171
# 20             Glenwood Ave -74.071061  40.727551        1159       819
# 21                 Grand St -74.037683  40.715178        4252      4057
# 22            Grove St PATH -74.043117  40.719586       40931     50623
# 23            Hamilton Park -74.044247  40.727596       20867     19661
# 24               Harborside -74.034234  40.719252       12105     11640
# 25         Heights Elevator -74.040443  40.748716        2567      2432
# 26                  Hilltop -74.057574  40.731169        3076      2401
# 27        JC Medical Center -74.049638  40.716540        5046      5336
# 28               JCBS Depot -74.068601  40.709651          53       221
# 29           Jackson Square -74.078900  40.711130         396       343
# 30             Jersey & 3rd -74.045953  40.723332        7973      7273
# 31          Jersey & 6th St -74.045572  40.725289        8035      6235
# 32           Journal Square -74.062500  40.733670        5819      5300
# 33           Lafayette Park -74.062859  40.713464        1913      2044
# 34      Leonard Gordon Park -74.057271  40.745910        2685      2455
# 35       Liberty Light Rail -74.055701  40.711242        7091      7392
# 36             Lincoln Park -74.078406  40.724605        2574      3218
# 37           MLK Light Rail -74.078885  40.711130          47        32
# 38             Manila & 1st -74.042884  40.721651        6527      6876
# 39         Marin Light Rail -74.042817  40.714584       10371     10117
# 40          McGinley Square -74.067622  40.725340        5629      4358
# 41         Monmouth and 6th -74.048790  40.725685        5894      5744
# 42            Montgomery St -74.050990  40.719420        2624      2419
# 43             Morris Canal -74.038526  40.712419       10534      8967
# 44                     NJCU -74.085849  40.710109          49        51
# 45               Newark Ave -74.046305  40.721525        9462      9583
# 46             Newport PATH -74.033759  40.727224       15247     16326
# 47             Newport Pkwy -74.032108  40.728745       10108     10036
# 48              Oakland Ave -74.052478  40.737604        5384      4049
# 49              Paulus Hook -74.033552  40.714145        8718      8226
# 50           Pershing Field -74.051789  40.742677        4426      4129
# 51           Riverview Park -74.043991  40.744319        2075      1733
# 52                  Sip Ave -74.063784  40.730743       18184     16310
# 53                 Union St -74.083639  40.718211        1015      1300
# 54           Van Vorst Park -74.047727  40.718489        9145      7939
# 55                Warren St -74.038051  40.721124        9258      9233
# 56     West Side Light Rail -74.088772  40.714402          42        96
# 57                  York St -74.041050  40.716490        3301      3040
#
#     total  months  avgtotal  avgstart  avgend
# 0    3777      12     314.8     168.8   145.9
# 1    5844      12     487.0     241.5   245.5
# 2    7533      12     627.8     339.1   288.7
# 3      65       5      13.0       6.8     6.2
# 4    4521       9     502.3     268.4   233.9
# 5      48       5       9.6       4.8     4.8
# 6   15548      12    1295.7     687.6   608.1
# 7   14200      12    1183.3     615.2   568.1
# 8    4055      12     337.9     201.7   136.2
# 9   18298      12    1524.8     735.8   789.1
# 10     36       4       9.0       3.5     5.5
# 11  14281      12    1190.1     596.4   593.7
# 12   2860      12     238.3     117.0   121.3
# 13     35       4       8.8       4.8     4.0
# 14   2785      12     232.1      97.3   134.8
# 15  10995      12     916.2     479.8   436.5
# 16  13547      12    1128.9     536.7   592.2
# 17  43075      12    3589.6    1580.8  2008.8
# 18   4457       9     495.2     281.3   213.9
# 19    326       4      81.5      38.8    42.8
# 20   1978       9     219.8     128.8    91.0
# 21   8309       9     923.2     472.4   450.8
# 22  91554      12    7629.5    3410.9  4218.6
# 23  40528      12    3377.3    1738.9  1638.4
# 24  23745      12    1978.8    1008.8   970.0
# 25   4999      12     416.6     213.9   202.7
# 26   5477      12     456.4     256.3   200.1
# 27  10382      12     865.2     420.5   444.7
# 28    274       6      45.7       8.8    36.8
# 29    739      12      61.6      33.0    28.6
# 30  15246      12    1270.5     664.4   606.1
# 31  14270      12    1189.2     669.6   519.6
# 32  11119      12     926.6     484.9   441.7
# 33   3957      12     329.8     159.4   170.3
# 34   5140      12     428.3     223.8   204.6
# 35  14483      12    1206.9     590.9   616.0
# 36   5792       4    1448.0     643.5   804.5
# 37     79      12       6.6       3.9     2.7
# 38  13403      12    1116.9     543.9   573.0
# 39  20488      12    1707.3     864.2   843.1
# 40   9987      12     832.2     469.1   363.2
# 41  11638       9    1293.1     654.9   638.2
# 42   5043      12     420.2     218.7   201.6
# 43  19501       4    4875.2    2633.5  2241.8
# 44    100      12       8.3       4.1     4.2
# 45  19045      12    1587.1     788.5   798.6
# 46  31573      12    2631.1    1270.6  1360.5
# 47  20144      12    1678.7     842.3   836.3
# 48   9433      12     786.1     448.7   337.4
# 49  16944      12    1412.0     726.5   685.5
# 50   8555      12     712.9     368.8   344.1
# 51   3808      12     317.3     172.9   144.4
# 52  34494      12    2874.5    1515.3  1359.2
# 53   2315      12     192.9      84.6   108.3
# 54  17084      12    1423.7     762.1   661.6
# 55  18491      12    1540.9     771.5   769.4
# 56    138       4      34.5      10.5    24.0
# 57   6341      12     528.4     275.1   253.3

# %%
def my_color_function_avg(feature):
    """Maps low values to green and hugh values to red."""
    if feature < station.avgtotal.quantile(.2):
        return '#FFF5EE'
    elif feature < station.avgtotal.quantile(.4):
        return '#FAD6A5'
    elif feature < station.avgtotal.quantile(.6):
        return '#FFB347'
    elif feature < station.avgtotal.quantile(.8):
        return '#FF8C00'
    else:
        return '#996515'

# %%
m = folium.Map([station['latitude'].mean(), station['longitude'].mean()],
               tiles='Stamen Terrain',
               zoom_start =13)

# mark each station as a point
for index, row in station.iterrows():
    
    html="""
    <div style="display:flex; flex-direction: column; justify-content:center;">
    <h3 style="text-align:center; font-family:sans-serif; margin-bottom:5px">{name}</h3>
    <div style="font-family:sans-serif; font-weight: bold;">Average Monthly Use</div>
    <div style="font-family:sans-serif; margin:0">Avg Departures: {start} </div>
    <div style="font-family:sans-serif;">Avg Arrivals: {end}</div>
    <div style="font-family:sans-serif;">Avg Monthly Total: {total}</div>
    </div>
    """.format(name=row['station'], start = row['avgstart'], end = row['avgend'], total = row['avgtotal'])
    
    iframe = branca.element.IFrame(html=html, width=200, height=150)

    folium.RegularPolygonMarker([row['latitude'], row['longitude']],
                        radius=8,
                        color= 'black',
                        fill_color= my_color_function_avg(row['avgtotal']),
                        popup=folium.Popup(iframe, max_width=2000),
                        ).add_to(m)

stationArr = list()

#for index, row in station.iterrows():
#    x = [row['latitude'], row['longitude']]
#    stationArr.append(x)

m.save('map2018.html')

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
